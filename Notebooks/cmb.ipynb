# %%
import matplotlib.pyplot as plt
import healpy as hp
# %matplotlib inline

# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from taunet.simulation import *
from taunet.Noise.ncm import NoiseModel

# %%
noise = NoiseModel()

# %%
hp.mollview(noise.noisemap(100))

# %% [markdown]
# # CMB

# %%
c = CMBmap(5,0.06)
QU = c.QU()

# %%
hp.mollview(QU[0], title='Q',sub=(1,2,1))
hp.mollview(QU[1], title='U',sub=(1,2,2))

# %% [markdown]
# # Noise

# %%
ncm = NoiseModel()
QU100 = ncm.noisemap(100)
QU143 = ncm.noisemap(143)

# %%
hp.mollview(QU100, title='100 GHz',sub=(1,2,1))
hp.mollview(QU143, title='143 GHz',sub=(1,2,2))

# %% [markdown]
# # FG

# %%
fg = FGround(["d0","s0"])
QUfg = fg.QU(100)

# %%
hp.mollview(QUfg[0], title='Q',sub=(1,2,1))
hp.mollview(QUfg[1], title='U',sub=(1,2,2))

# %%
#test
