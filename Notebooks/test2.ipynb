# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import healpy as hp
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from taunet.ncm import NoiseModel
from taunet.simulation import CMBmap, FGMap, SkySimulation,CMBspectra
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main_dir = '/marconi/home/userexternal/aidicher/storage/TAUNET'

# %%
sky = SkySimulation(main_dir,0.06)
# Out:
# tau = 0.06

# %%
fg = sky.qu_fg_23

# %%
QU = sky.QU(23,0,'uK')

# %%
hp.mollview((QU[0]-fg[0])*sky.mask, title='Q')
